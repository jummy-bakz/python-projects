# %% [markdown]
# #import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns       
import numpy as np
# %matplotlib inline

# %% [markdown]
# Investigating the shape of Data

# %%
df = pd.read_csv('tmdb-movies.csv')

# %%
df
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...                             ...
# 10861            The Endless Summer
# 10862                    Grand Prix
# 10863           Beregis Avtomobilya
# 10864        What's Up, Tiger Lily?
# 10865      Manos: The Hands of Fate
#
#                                                     cast  \
# 0      Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1      Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2      Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3      Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4      Vin Diesel|Paul Walker|Jason Statham|Michelle ...
# ...                                                  ...
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...
#
#                                                 homepage            director  \
# 0                          http://www.jurassicworld.com/     Colin Trevorrow
# 1                            http://www.madmaxmovie.com/       George Miller
# 2         http://www.thedivergentseries.movie/#insurgent    Robert Schwentke
# 3      http://www.starwars.com/films/star-wars-episod...         J.J. Abrams
# 4                               http://www.furious7.com/           James Wan
# ...                                                  ...                 ...
# 10861                                                NaN         Bruce Brown
# 10862                                                NaN  John Frankenheimer
# 10863                                                NaN      Eldar Ryazanov
# 10864                                                NaN         Woody Allen
# 10865                                                NaN    Harold P. Warren
#
#                                                  tagline  ...  \
# 0                                      The park is open.  ...
# 1                                     What a Lovely Day.  ...
# 2                             One Choice Can Destroy You  ...
# 3                          Every generation has a story.  ...
# 4                                    Vengeance Hits Home  ...
# ...                                                  ...  ...
# 10861                                                NaN  ...
# 10862  Cinerama sweeps YOU into a drama of speed and ...  ...
# 10863                                                NaN  ...
# 10864                          WOODY ALLEN STRIKES BACK!  ...
# 10865       It's Shocking! It's Beyond Your Imagination!  ...
#
#                                                 overview runtime  \
# 0      Twenty-two years after the events of Jurassic ...     124
# 1      An apocalyptic story set in the furthest reach...     120
# 2      Beatrice Prior must confront her inner demons ...     119
# 3      Thirty years after defeating the Galactic Empi...     136
# 4      Deckard Shaw seeks revenge against Dominic Tor...     137
# ...                                                  ...     ...
# 10861  The Endless Summer, by Bruce Brown, is one of ...      95
# 10862  Grand Prix driver Pete Aron is fired by his te...     176
# 10863  An insurance agent who moonlights as a carthie...      94
# 10864  In comic Woody Allen's film debut, he took the...      80
# 10865  A family gets lost on the road and stumbles up...      74
#
#                                           genres  \
# 0      Action|Adventure|Science Fiction|Thriller
# 1      Action|Adventure|Science Fiction|Thriller
# 2             Adventure|Science Fiction|Thriller
# 3       Action|Adventure|Science Fiction|Fantasy
# 4                          Action|Crime|Thriller
# ...                                          ...
# 10861                                Documentary
# 10862                     Action|Adventure|Drama
# 10863                             Mystery|Comedy
# 10864                              Action|Comedy
# 10865                                     Horror
#
#                                     production_companies release_date  \
# 0      Universal Studios|Amblin Entertainment|Legenda...     6/9/2015
# 1      Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015
# 2      Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015
# 3              Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015
# 4      Universal Pictures|Original Film|Media Rights ...     4/1/2015
# ...                                                  ...          ...
# 10861                                  Bruce Brown Films    6/15/1966
# 10862  Cherokee Productions|Joel Productions|Douglas ...   12/21/1966
# 10863                                            Mosfilm     1/1/1966
# 10864                            Benedict Pictures Corp.    11/2/1966
# 10865                                          Norm-Iris   11/15/1966
#
#       vote_count  vote_average  release_year    budget_adj   revenue_adj
# 0           5562           6.5          2015  1.379999e+08  1.392446e+09
# 1           6185           7.1          2015  1.379999e+08  3.481613e+08
# 2           2480           6.3          2015  1.012000e+08  2.716190e+08
# 3           5292           7.5          2015  1.839999e+08  1.902723e+09
# 4           2947           7.3          2015  1.747999e+08  1.385749e+09
# ...          ...           ...           ...           ...           ...
# 10861         11           7.4          1966  0.000000e+00  0.000000e+00
# 10862         20           5.7          1966  0.000000e+00  0.000000e+00
# 10863         11           6.5          1966  0.000000e+00  0.000000e+00
# 10864         22           5.4          1966  0.000000e+00  0.000000e+00
# 10865         15           1.5          1966  1.276423e+05  0.000000e+00
#
# [10866 rows x 21 columns]

# %%
df.head
# Out:
# <bound method NDFrame.head of            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...                             ...
# 10861            The Endless Summer
# 10862                    Grand Prix
# 10863           Beregis Avtomobilya
# 10864        What's Up, Tiger Lily?
# 10865      Manos: The Hands of Fate
#
#                                                     cast  \
# 0      Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1      Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2      Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3      Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4      Vin Diesel|Paul Walker|Jason Statham|Michelle ...
# ...                                                  ...
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...
#
#                                                 homepage            director  \
# 0                          http://www.jurassicworld.com/     Colin Trevorrow
# 1                            http://www.madmaxmovie.com/       George Miller
# 2         http://www.thedivergentseries.movie/#insurgent    Robert Schwentke
# 3      http://www.starwars.com/films/star-wars-episod...         J.J. Abrams
# 4                               http://www.furious7.com/           James Wan
# ...                                                  ...                 ...
# 10861                                                NaN         Bruce Brown
# 10862                                                NaN  John Frankenheimer
# 10863                                                NaN      Eldar Ryazanov
# 10864                                                NaN         Woody Allen
# 10865                                                NaN    Harold P. Warren
#
#                                                  tagline  ...  \
# 0                                      The park is open.  ...
# 1                                     What a Lovely Day.  ...
# 2                             One Choice Can Destroy You  ...
# 3                          Every generation has a story.  ...
# 4                                    Vengeance Hits Home  ...
# ...                                                  ...  ...
# 10861                                                NaN  ...
# 10862  Cinerama sweeps YOU into a drama of speed and ...  ...
# 10863                                                NaN  ...
# 10864                          WOODY ALLEN STRIKES BACK!  ...
# 10865       It's Shocking! It's Beyond Your Imagination!  ...
#
#                                                 overview runtime  \
# 0      Twenty-two years after the events of Jurassic ...     124
# 1      An apocalyptic story set in the furthest reach...     120
# 2      Beatrice Prior must confront her inner demons ...     119
# 3      Thirty years after defeating the Galactic Empi...     136
# 4      Deckard Shaw seeks revenge against Dominic Tor...     137
# ...                                                  ...     ...
# 10861  The Endless Summer, by Bruce Brown, is one of ...      95
# 10862  Grand Prix driver Pete Aron is fired by his te...     176
# 10863  An insurance agent who moonlights as a carthie...      94
# 10864  In comic Woody Allen's film debut, he took the...      80
# 10865  A family gets lost on the road and stumbles up...      74
#
#                                           genres  \
# 0      Action|Adventure|Science Fiction|Thriller
# 1      Action|Adventure|Science Fiction|Thriller
# 2             Adventure|Science Fiction|Thriller
# 3       Action|Adventure|Science Fiction|Fantasy
# 4                          Action|Crime|Thriller
# ...                                          ...
# 10861                                Documentary
# 10862                     Action|Adventure|Drama
# 10863                             Mystery|Comedy
# 10864                              Action|Comedy
# 10865                                     Horror
#
#                                     production_companies release_date  \
# 0      Universal Studios|Amblin Entertainment|Legenda...     6/9/2015
# 1      Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015
# 2      Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015
# 3              Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015
# 4      Universal Pictures|Original Film|Media Rights ...     4/1/2015
# ...                                                  ...          ...
# 10861                                  Bruce Brown Films    6/15/1966
# 10862  Cherokee Productions|Joel Productions|Douglas ...   12/21/1966
# 10863                                            Mosfilm     1/1/1966
# 10864                            Benedict Pictures Corp.    11/2/1966
# 10865                                          Norm-Iris   11/15/1966
#
#       vote_count  vote_average  release_year    budget_adj   revenue_adj
# 0           5562           6.5          2015  1.379999e+08  1.392446e+09
# 1           6185           7.1          2015  1.379999e+08  3.481613e+08
# 2           2480           6.3          2015  1.012000e+08  2.716190e+08
# 3           5292           7.5          2015  1.839999e+08  1.902723e+09
# 4           2947           7.3          2015  1.747999e+08  1.385749e+09
# ...          ...           ...           ...           ...           ...
# 10861         11           7.4          1966  0.000000e+00  0.000000e+00
# 10862         20           5.7          1966  0.000000e+00  0.000000e+00
# 10863         11           6.5          1966  0.000000e+00  0.000000e+00
# 10864         22           5.4          1966  0.000000e+00  0.000000e+00
# 10865         15           1.5          1966  1.276423e+05  0.000000e+00
#
# [10866 rows x 21 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
#  15  release_date          10866 non-null  object
#  16  vote_count            10866 non-null  int64
#  17  vote_average          10866 non-null  float64
#  18  release_year          10866 non-null  int64
#  19  budget_adj            10866 non-null  float64
#  20  revenue_adj           10866 non-null  float64
# dtypes: float64(4), int64(6), object(11)
# memory usage: 1.7+ MB

# %% [markdown]
# # To check the number of rows and columns

# %%
df.tail()
# Out:
#           id    imdb_id  popularity  budget  revenue  \
# 10861     21  tt0060371    0.080598       0        0
# 10862  20379  tt0060472    0.065543       0        0
# 10863  39768  tt0060161    0.065141       0        0
# 10864  21449  tt0061177    0.064317       0        0
# 10865  22293  tt0060666    0.035919   19000        0
#
#                  original_title  \
# 10861        The Endless Summer
# 10862                Grand Prix
# 10863       Beregis Avtomobilya
# 10864    What's Up, Tiger Lily?
# 10865  Manos: The Hands of Fate
#
#                                                     cast homepage  \
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...      NaN
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...      NaN
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...      NaN
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...      NaN
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...      NaN
#
#                  director                                            tagline  \
# 10861         Bruce Brown                                                NaN
# 10862  John Frankenheimer  Cinerama sweeps YOU into a drama of speed and ...
# 10863      Eldar Ryazanov                                                NaN
# 10864         Woody Allen                          WOODY ALLEN STRIKES BACK!
# 10865    Harold P. Warren       It's Shocking! It's Beyond Your Imagination!
#
#        ...                                           overview runtime  \
# 10861  ...  The Endless Summer, by Bruce Brown, is one of ...      95
# 10862  ...  Grand Prix driver Pete Aron is fired by his te...     176
# 10863  ...  An insurance agent who moonlights as a carthie...      94
# 10864  ...  In comic Woody Allen's film debut, he took the...      80
# 10865  ...  A family gets lost on the road and stumbles up...      74
#
#                        genres  \
# 10861             Documentary
# 10862  Action|Adventure|Drama
# 10863          Mystery|Comedy
# 10864           Action|Comedy
# 10865                  Horror
#
#                                     production_companies release_date  \
# 10861                                  Bruce Brown Films    6/15/1966
# 10862  Cherokee Productions|Joel Productions|Douglas ...   12/21/1966
# 10863                                            Mosfilm     1/1/1966
# 10864                            Benedict Pictures Corp.    11/2/1966
# 10865                                          Norm-Iris   11/15/1966
#
#       vote_count  vote_average  release_year   budget_adj  revenue_adj
# 10861         11           7.4          1966       0.0000          0.0
# 10862         20           5.7          1966       0.0000          0.0
# 10863         11           6.5          1966       0.0000          0.0
# 10864         22           5.4          1966       0.0000          0.0
# 10865         15           1.5          1966  127642.2792          0.0
#
# [5 rows x 21 columns]

# %%
# statistic values for this data

# %%
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# std      575.619058      0.935142     12.812941  3.430616e+07  1.446325e+08
# min       10.000000      1.500000   1960.000000  0.000000e+00  0.000000e+00
# 25%       17.000000      5.400000   1995.000000  0.000000e+00  0.000000e+00
# 50%       38.000000      6.000000   2006.000000  0.000000e+00  0.000000e+00
# 75%      145.750000      6.600000   2011.000000  2.085325e+07  3.369710e+07
# max     9767.000000      9.200000   2015.000000  4.250000e+08  2.827124e+09

# %% [markdown]
# # check the rows and columns of this dataset
# e

# %%
df.shape
# Out:
# (10866, 21)

# %% [markdown]
# # check each columns number of unique values

# %%
df.nunique()
# Out:
# id                      10865
# imdb_id                 10855
# popularity              10814
# budget                    557
# revenue                  4702
# original_title          10571
# cast                    10719
# homepage                 2896
# director                 5067
# tagline                  7997
# keywords                 8804
# overview                10847
# runtime                   247
# genres                   2039
# production_companies     7445
# release_date             5909
# vote_count               1289
# vote_average               72
# release_year               56
# budget_adj               2614
# revenue_adj              4840
# dtype: int64

# %%
df.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %% [markdown]
# # Data cleaning process by filling null values with mean and also drop duplicate data

# %%
df.drop(['id','imdb_id', 'homepage','overview'],axis=1,inplace=True)

# %%
df
# Out:
#        popularity     budget     revenue                original_title  \
# 0       32.985763  150000000  1513528810                Jurassic World
# 1       28.419936  150000000   378436354            Mad Max: Fury Road
# 2       13.112507  110000000   295238201                     Insurgent
# 3       11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4        9.335014  190000000  1506249360                     Furious 7
# ...           ...        ...         ...                           ...
# 10861    0.080598          0           0            The Endless Summer
# 10862    0.065543          0           0                    Grand Prix
# 10863    0.065141          0           0           Beregis Avtomobilya
# 10864    0.064317          0           0        What's Up, Tiger Lily?
# 10865    0.035919      19000           0      Manos: The Hands of Fate
#
#                                                     cast            director  \
# 0      Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...     Colin Trevorrow
# 1      Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...       George Miller
# 2      Shailene Woodley|Theo James|Kate Winslet|Ansel...    Robert Schwentke
# 3      Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...         J.J. Abrams
# 4      Vin Diesel|Paul Walker|Jason Statham|Michelle ...           James Wan
# ...                                                  ...                 ...
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...         Bruce Brown
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...  John Frankenheimer
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...      Eldar Ryazanov
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...         Woody Allen
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...    Harold P. Warren
#
#                                                  tagline  \
# 0                                      The park is open.
# 1                                     What a Lovely Day.
# 2                             One Choice Can Destroy You
# 3                          Every generation has a story.
# 4                                    Vengeance Hits Home
# ...                                                  ...
# 10861                                                NaN
# 10862  Cinerama sweeps YOU into a drama of speed and ...
# 10863                                                NaN
# 10864                          WOODY ALLEN STRIKES BACK!
# 10865       It's Shocking! It's Beyond Your Imagination!
#
#                                                 keywords  runtime  \
# 0      monster|dna|tyrannosaurus rex|velociraptor|island      124
# 1       future|chase|post-apocalyptic|dystopia|australia      120
# 2      based on novel|revolution|dystopia|sequel|dyst...      119
# 3                  android|spaceship|jedi|space opera|3d      136
# 4                    car race|speed|revenge|suspense|car      137
# ...                                                  ...      ...
# 10861                           surfer|surfboard|surfing       95
# 10862                          car race|racing|formula 1      176
# 10863                           car|trolley|stealing car       94
# 10864                                              spoof       80
# 10865                fire|gun|drive|sacrifice|flashlight       74
#
#                                           genres  \
# 0      Action|Adventure|Science Fiction|Thriller
# 1      Action|Adventure|Science Fiction|Thriller
# 2             Adventure|Science Fiction|Thriller
# 3       Action|Adventure|Science Fiction|Fantasy
# 4                          Action|Crime|Thriller
# ...                                          ...
# 10861                                Documentary
# 10862                     Action|Adventure|Drama
# 10863                             Mystery|Comedy
# 10864                              Action|Comedy
# 10865                                     Horror
#
#                                     production_companies release_date  \
# 0      Universal Studios|Amblin Entertainment|Legenda...     6/9/2015
# 1      Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015
# 2      Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015
# 3              Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015
# 4      Universal Pictures|Original Film|Media Rights ...     4/1/2015
# ...                                                  ...          ...
# 10861                                  Bruce Brown Films    6/15/1966
# 10862  Cherokee Productions|Joel Productions|Douglas ...   12/21/1966
# 10863                                            Mosfilm     1/1/1966
# 10864                            Benedict Pictures Corp.    11/2/1966
# 10865                                          Norm-Iris   11/15/1966
#
#        vote_count  vote_average  release_year    budget_adj   revenue_adj
# 0            5562           6.5          2015  1.379999e+08  1.392446e+09
# 1            6185           7.1          2015  1.379999e+08  3.481613e+08
# 2            2480           6.3          2015  1.012000e+08  2.716190e+08
# 3            5292           7.5          2015  1.839999e+08  1.902723e+09
# 4            2947           7.3          2015  1.747999e+08  1.385749e+09
# ...           ...           ...           ...           ...           ...
# 10861          11           7.4          1966  0.000000e+00  0.000000e+00
# 10862          20           5.7          1966  0.000000e+00  0.000000e+00
# 10863          11           6.5          1966  0.000000e+00  0.000000e+00
# 10864          22           5.4          1966  0.000000e+00  0.000000e+00
# 10865          15           1.5          1966  1.276423e+05  0.000000e+00
#
# [10866 rows x 17 columns]

# %%
df=df.fillna(0)

# %%
df.isnull().mean()
# Out:
# popularity              0.0
# budget                  0.0
# revenue                 0.0
# original_title          0.0
# cast                    0.0
# director                0.0
# tagline                 0.0
# keywords                0.0
# runtime                 0.0
# genres                  0.0
# production_companies    0.0
# release_date            0.0
# vote_count              0.0
# vote_average            0.0
# release_year            0.0
# budget_adj              0.0
# revenue_adj             0.0
# dtype: float64

# %% [markdown]
# # calculate sum of null value for each columns

# %%
df.isnull().sum()
# Out:
# popularity              0
# budget                  0
# revenue                 0
# original_title          0
# cast                    0
# director                0
# tagline                 0
# keywords                0
# runtime                 0
# genres                  0
# production_companies    0
# release_date            0
# vote_count              0
# vote_average            0
# release_year            0
# budget_adj              0
# revenue_adj             0
# dtype: int64

# %% [markdown]
# # Drop null values for each coloumn containing null values

# %%
df.dropna(inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   popularity            10866 non-null  float64
#  1   budget                10866 non-null  int64
#  2   revenue               10866 non-null  int64
#  3   original_title        10866 non-null  object
#  4   cast                  10866 non-null  object
#  5   director              10866 non-null  object
#  6   tagline               10866 non-null  object
#  7   keywords              10866 non-null  object
#  8   runtime               10866 non-null  int64
#  9   genres                10866 non-null  object
#  10  production_companies  10866 non-null  object
#  11  release_date          10866 non-null  object
#  12  vote_count            10866 non-null  int64
#  13  vote_average          10866 non-null  float64
#  14  release_year          10866 non-null  int64
#  15  budget_adj            10866 non-null  float64
#  16  revenue_adj           10866 non-null  float64
# dtypes: float64(4), int64(5), object(8)
# memory usage: 1.4+ MB

# %% [markdown]
# # To replace all the zero value in columns with mean value

# %%
df['popularity']=df['popularity'].replace(0,df['popularity'].mean())
df['revenue']=df['revenue'].replace(0,df['revenue'].mean())
df['runtime']=df['runtime'].replace(0,df['runtime'].mean())
df['budget_adj']=df['budget_adj'].replace(0,df['budget_adj'].mean())
df['revenue_adj']=df['revenue_adj'].replace(0,df['revenue_adj'].mean())

# %%
df.describe()
# Out:
#          popularity        budget       revenue       runtime    vote_count  \
# count  10866.000000  1.086600e+04  1.086600e+04  10866.000000  10866.000000
# mean       0.646441  1.462570e+07  6.187164e+07    102.362065    217.389748
# std        1.000185  3.091321e+07  1.110204e+08     30.902781    575.619058
# min        0.000065  0.000000e+00  2.000000e+00      2.000000     10.000000
# 25%        0.207583  0.000000e+00  3.982332e+07     90.000000     17.000000
# 50%        0.383856  0.000000e+00  3.982332e+07     99.000000     38.000000
# 75%        0.713817  1.500000e+07  3.982332e+07    111.000000    145.750000
# max       32.985763  4.250000e+08  2.781506e+09    900.000000   9767.000000
#
#        vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean       5.974922   2001.322658  2.675136e+07  7.980243e+07
# std        0.935142     12.812941  3.050850e+07  1.365610e+08
# min        1.500000   1960.000000  9.210911e-01  2.370705e+00
# 25%        5.400000   1995.000000  1.755104e+07  5.136436e+07
# 50%        6.000000   2006.000000  1.755104e+07  5.136436e+07
# 75%        6.600000   2011.000000  2.085325e+07  5.136436e+07
# max        9.200000   2015.000000  4.250000e+08  2.827124e+09

# %% [markdown]
# # calculate sum of all duplicated value
# )

# %%
df.duplicated().sum()
# Out:
# 1

# %%
# Drop duplicate value

# %%
df.drop_duplicates(inplace=True)

# %%
# calculate sum of all duplicated value

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Visualization of each variables

# %%
df.hist(figsize=(18,18));

# %% [markdown]
# ## Exploration with Visuals and Conclusions
#
# # The questions about this dataset;
#
# 1.Does higher budget mean higher popularity ?
#
# 2.Do the runtime affect the vote count and popularity?
#
# 3.Is Higher popularity means higher profits ?
#
# 4.What are the Features Associate with Top 10 Revenue Movies ?

# %% [markdown]
# EVALUATING QUESTION 1
#
# 1.Does higher budget mean higher popularity ?

# %%
# plot the relation between budget and popularity 
x = df['budget']
y = df['popularity'] 

plt.scatter(x,y)
plt.title('Average Popularity by Different budget',fontsize=18)
plt.xlabel('budget',fontsize=20)
plt.ylabel('popularity',fontsize=20)
# Out:
# Text(0, 0.5, 'popularity')

# %% [markdown]
# As per the above scatter plot its very difficult to observe strong relationship between popularity and budget.
# So we use other method to observe the relationship between them.
# In this method we divide data set into two group on the basis of median.

# %%
# divide the budget into two groups : lesser_cost and more_cost.
med = df['budget'].median()
lesser_cost =  df.query('budget < {}'.format(med))
more_cost =  df.query('budget >= {}'.format(med))

# %%
# check lesser cost and more cost  mean values 
mean_low_budget = lesser_cost['popularity'].mean()
mean_high_budget = more_cost['popularity'].mean()

# %%
# create a bar chart with the values we get above 
locations = [1,2]
heights = [mean_low_budget , mean_high_budget]
labels=['low','high']
plt.bar(locations, heights, tick_label = labels)
plt.title('Mean Popularity by all Budget')
plt.xlabel('Budgets')
plt.ylabel('Mean Popularity')
# Out:
# Text(0, 0.5, 'Mean Popularity')

# %%
increase_percentage = (mean_high_budget - mean_low_budget) / mean_high_budget * 100
increase_percentage
# Out:
# nan

# %% [markdown]
# Answer for question 1
#
# From the above bar plot we conclude that higher budget movie gains higher popularity.

# %% [markdown]
# EVALUATING QUESTION 2
#
# 2.Do the runtime affect the vote count and popularity?

# %%
# There 3 groups with query().  <60 min: lowest   , 60 min <=  <= - 120 min: medium ,  >120 min: highest
lowest =  df.query('runtime < {}'.format(100))
med =  df.query('runtime < {}'.format(200))
highest = df.query('runtime > {}'.format(200))

# %%
# check mean popularity of different movie lengths 
mean_of_lowest = lowest['popularity'].mean()
mean_of_med = med['popularity'].mean()
mean_of_highest = highest['popularity'].mean()

# %%
locations = [1,2,3]
heights = [mean_of_lowest, mean_of_med, mean_of_highest]
labels=['low','medium','high']
plt.bar(locations, heights, tick_label = labels)
plt.title('Average Popularity by Different Runtime')
plt.xlabel('Runtime')
plt.ylabel('Average Popularity')
# Out:
# Text(0, 0.5, 'Average Popularity')

# %%
# scatter plot between runtime and popularity 
x = df['runtime']
y = df['popularity'] 

plt.scatter(x,y)

plt.title('Average Popularity by Different Runtime',fontsize=20)
plt.xlabel('runtime',fontsize=20)
plt.ylabel('popularity',fontsize=20)
# Out:
# Text(0, 0.5, 'popularity')

# %% [markdown]
# ANSWER FOR QUESTION 2
#
# From the above two plots, we can simply say that If the movies are within 200 minutes,it will be more popular.
# Once the movies run over 200 minutes, it's hard for them to gain high popularity

# %% [markdown]
# EVALUATING QUESTION 3
#
# 3.Is Higher popularity means higher profits ?

# %%
# calculation for the mean of popularity 
mean = df['popularity'].median()
lowest_popularity =  df.query('popularity < {}'.format(mean))
more_popularity =  df.query('popularity >= {}'.format(mean))

# %%
# create a new column called profit.
df['profit'] = df['revenue'] - df['budget']

# %%
df
# Out:
#        popularity     budget       revenue                original_title  \
# 0       32.985763  150000000  1.513529e+09                Jurassic World
# 1       28.419936  150000000  3.784364e+08            Mad Max: Fury Road
# 2       13.112507  110000000  2.952382e+08                     Insurgent
# 3       11.173104  200000000  2.068178e+09  Star Wars: The Force Awakens
# 4        9.335014  190000000  1.506249e+09                     Furious 7
# ...           ...        ...           ...                           ...
# 10861    0.080598          0  3.982332e+07            The Endless Summer
# 10862    0.065543          0  3.982332e+07                    Grand Prix
# 10863    0.065141          0  3.982332e+07           Beregis Avtomobilya
# 10864    0.064317          0  3.982332e+07        What's Up, Tiger Lily?
# 10865    0.035919      19000  3.982332e+07      Manos: The Hands of Fate
#
#                                                     cast            director  \
# 0      Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...     Colin Trevorrow
# 1      Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...       George Miller
# 2      Shailene Woodley|Theo James|Kate Winslet|Ansel...    Robert Schwentke
# 3      Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...         J.J. Abrams
# 4      Vin Diesel|Paul Walker|Jason Statham|Michelle ...           James Wan
# ...                                                  ...                 ...
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...         Bruce Brown
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...  John Frankenheimer
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...      Eldar Ryazanov
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...         Woody Allen
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...    Harold P. Warren
#
#                                                  tagline  \
# 0                                      The park is open.
# 1                                     What a Lovely Day.
# 2                             One Choice Can Destroy You
# 3                          Every generation has a story.
# 4                                    Vengeance Hits Home
# ...                                                  ...
# 10861                                                  0
# 10862  Cinerama sweeps YOU into a drama of speed and ...
# 10863                                                  0
# 10864                          WOODY ALLEN STRIKES BACK!
# 10865       It's Shocking! It's Beyond Your Imagination!
#
#                                                 keywords  runtime  \
# 0      monster|dna|tyrannosaurus rex|velociraptor|island    124.0
# 1       future|chase|post-apocalyptic|dystopia|australia    120.0
# 2      based on novel|revolution|dystopia|sequel|dyst...    119.0
# 3                  android|spaceship|jedi|space opera|3d    136.0
# 4                    car race|speed|revenge|suspense|car    137.0
# ...                                                  ...      ...
# 10861                           surfer|surfboard|surfing     95.0
# 10862                          car race|racing|formula 1    176.0
# 10863                           car|trolley|stealing car     94.0
# 10864                                              spoof     80.0
# 10865                fire|gun|drive|sacrifice|flashlight     74.0
#
#                                           genres  \
# 0      Action|Adventure|Science Fiction|Thriller
# 1      Action|Adventure|Science Fiction|Thriller
# 2             Adventure|Science Fiction|Thriller
# 3       Action|Adventure|Science Fiction|Fantasy
# 4                          Action|Crime|Thriller
# ...                                          ...
# 10861                                Documentary
# 10862                     Action|Adventure|Drama
# 10863                             Mystery|Comedy
# 10864                              Action|Comedy
# 10865                                     Horror
#
#                                     production_companies release_date  \
# 0      Universal Studios|Amblin Entertainment|Legenda...     6/9/2015
# 1      Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015
# 2      Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015
# 3              Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015
# 4      Universal Pictures|Original Film|Media Rights ...     4/1/2015
# ...                                                  ...          ...
# 10861                                  Bruce Brown Films    6/15/1966
# 10862  Cherokee Productions|Joel Productions|Douglas ...   12/21/1966
# 10863                                            Mosfilm     1/1/1966
# 10864                            Benedict Pictures Corp.    11/2/1966
# 10865                                          Norm-Iris   11/15/1966
#
#        vote_count  vote_average  release_year    budget_adj   revenue_adj  \
# 0            5562           6.5          2015  1.379999e+08  1.392446e+09
# 1            6185           7.1          2015  1.379999e+08  3.481613e+08
# 2            2480           6.3          2015  1.012000e+08  2.716190e+08
# 3            5292           7.5          2015  1.839999e+08  1.902723e+09
# 4            2947           7.3          2015  1.747999e+08  1.385749e+09
# ...           ...           ...           ...           ...           ...
# 10861          11           7.4          1966  1.755104e+07  5.136436e+07
# 10862          20           5.7          1966  1.755104e+07  5.136436e+07
# 10863          11           6.5          1966  1.755104e+07  5.136436e+07
# 10864          22           5.4          1966  1.755104e+07  5.136436e+07
# 10865          15           1.5          1966  1.276423e+05  5.136436e+07
#
#              profit
# 0      1.363529e+09
# 1      2.284364e+08
# 2      1.852382e+08
# 3      1.868178e+09
# 4      1.316249e+09
# ...             ...
# 10861  3.982332e+07
# 10862  3.982332e+07
# 10863  3.982332e+07
# 10864  3.982332e+07
# 10865  3.980432e+07
#
# [10865 rows x 18 columns]

# %%
df['profit']
# Out:
# 0        1.363529e+09
# 1        2.284364e+08
# 2        1.852382e+08
# 3        1.868178e+09
# 4        1.316249e+09
#              ...
# 10861    3.982332e+07
# 10862    3.982332e+07
# 10863    3.982332e+07
# 10864    3.982332e+07
# 10865    3.980432e+07
# Name: profit, Length: 10865, dtype: float64

# %%
lowest_popularity
# Out:
#        popularity  budget       revenue                      original_title  \
# 298      0.370258       0  3.982332e+07         The Girl in the Photographs
# 305      0.250209       0  3.982332e+07  The Lion Guard: Return of the Roar
# 314      0.383406       0  4.997000e+04                              Spring
# 315      0.383183       0  3.982332e+07                       The Intruders
# 316      0.382997       0  3.982332e+07                   We Are Still Here
# ...           ...     ...           ...                                 ...
# 10861    0.080598       0  3.982332e+07                  The Endless Summer
# 10862    0.065543       0  3.982332e+07                          Grand Prix
# 10863    0.065141       0  3.982332e+07                 Beregis Avtomobilya
# 10864    0.064317       0  3.982332e+07              What's Up, Tiger Lily?
# 10865    0.035919   19000  3.982332e+07            Manos: The Hands of Fate
#
#                                                     cast  \
# 298    Kal Penn|Claudia Lee|Kenny Wormald|Toby Heming...
# 305    Max Charles|Jeff Bennett|Dusan Brown|Sarah Hyl...
# 314    Lou Taylor Pucci|Nadia Hilker|Nick Nevern|Augi...
# 315    Miranda Cosgrove|Donal Logue|Tom Sizemore|Jene...
# 316    Barbara Crampton|Andrew Sensenig|Lisa Marie|La...
# ...                                                  ...
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...
#
#                            director  \
# 298                      Nick Simon
# 305                    Howy Parkins
# 314    Aaron Moorhead|Justin Benson
# 315                     Adam Massey
# 316                   Ted Geoghegan
# ...                             ...
# 10861                   Bruce Brown
# 10862            John Frankenheimer
# 10863                Eldar Ryazanov
# 10864                   Woody Allen
# 10865              Harold P. Warren
#
#                                                  tagline  \
# 298                                                    0
# 305                                                    0
# 314                                   Love is a monster.
# 315                You can't lock out what lives inside.
# 316                           This house needs a family.
# ...                                                  ...
# 10861                                                  0
# 10862  Cinerama sweeps YOU into a drama of speed and ...
# 10863                                                  0
# 10864                          WOODY ALLEN STRIKES BACK!
# 10865       It's Shocking! It's Beyond Your Imagination!
#
#                                              keywords  runtime  \
# 298    serial killer|tied feet|tied up while barefoot     95.0
# 305                                                 0     44.0
# 314                                                 0    109.0
# 315                                                 0     92.0
# 316     terror|countryside|secret|supernatural|spirit     84.0
# ...                                               ...      ...
# 10861                        surfer|surfboard|surfing     95.0
# 10862                       car race|racing|formula 1    176.0
# 10863                        car|trolley|stealing car     94.0
# 10864                                           spoof     80.0
# 10865             fire|gun|drive|sacrifice|flashlight     74.0
#
#                                genres  \
# 298             Crime|Horror|Thriller
# 305         Family|TV Movie|Animation
# 314    Horror|Romance|Science Fiction
# 315                          Thriller
# 316                            Horror
# ...                               ...
# 10861                     Documentary
# 10862          Action|Adventure|Drama
# 10863                  Mystery|Comedy
# 10864                   Action|Comedy
# 10865                          Horror
#
#                                     production_companies release_date  \
# 298                                                    0    9/14/2015
# 305                     Walt Disney Television Animation   11/22/2015
# 314                                            XYZ Films    3/20/2015
# 315                                         Darius Films    2/24/2015
# 316                     Dark Sky Films|Snowfort Pictures     6/5/2015
# ...                                                  ...          ...
# 10861                                  Bruce Brown Films    6/15/1966
# 10862  Cherokee Productions|Joel Productions|Douglas ...   12/21/1966
# 10863                                            Mosfilm     1/1/1966
# 10864                            Benedict Pictures Corp.    11/2/1966
# 10865                                          Norm-Iris   11/15/1966
#
#        vote_count  vote_average  release_year    budget_adj   revenue_adj  \
# 298            10           4.7          2015  1.755104e+07  5.136436e+07
# 305            48           5.9          2015  1.755104e+07  5.136436e+07
# 314           110           6.5          2015  1.755104e+07  4.597238e+04
# 315            26           4.9          2015  1.755104e+07  5.136436e+07
# 316            91           5.5          2015  1.755104e+07  5.136436e+07
# ...           ...           ...           ...           ...           ...
# 10861          11           7.4          1966  1.755104e+07  5.136436e+07
# 10862          20           5.7          1966  1.755104e+07  5.136436e+07
# 10863          11           6.5          1966  1.755104e+07  5.136436e+07
# 10864          22           5.4          1966  1.755104e+07  5.136436e+07
# 10865          15           1.5          1966  1.276423e+05  5.136436e+07
#
#              profit
# 298    3.982332e+07
# 305    3.982332e+07
# 314    4.997000e+04
# 315    3.982332e+07
# 316    3.982332e+07
# ...             ...
# 10861  3.982332e+07
# 10862  3.982332e+07
# 10863  3.982332e+07
# 10864  3.982332e+07
# 10865  3.980432e+07
#
# [5432 rows x 18 columns]

# %%
more_popularity
# Out:
#        popularity     budget       revenue                original_title  \
# 0       32.985763  150000000  1.513529e+09                Jurassic World
# 1       28.419936  150000000  3.784364e+08            Mad Max: Fury Road
# 2       13.112507  110000000  2.952382e+08                     Insurgent
# 3       11.173104  200000000  2.068178e+09  Star Wars: The Force Awakens
# 4        9.335014  190000000  1.506249e+09                     Furious 7
# ...           ...        ...           ...                           ...
# 10827    0.410366    1377800  3.982332e+07                        Batman
# 10828    0.402730    3000000  1.300000e+07                  Torn Curtain
# 10829    0.395668    4653000  6.000000e+06                     El Dorado
# 10831    0.529721          0  3.982332e+07            The Fortune Cookie
# 10833    0.737730          0  3.982332e+07        How to Steal a Million
#
#                                                     cast             director  \
# 0      Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...      Colin Trevorrow
# 1      Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...        George Miller
# 2      Shailene Woodley|Theo James|Kate Winslet|Ansel...     Robert Schwentke
# 3      Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...          J.J. Abrams
# 4      Vin Diesel|Paul Walker|Jason Statham|Michelle ...            James Wan
# ...                                                  ...                  ...
# 10827  Adam West|Burt Ward|Cesar Romero|Burgess Mered...  Leslie H. Martinson
# 10828  Paul Newman|Julie Andrews|Lila Kedrova|Hansj̦...     Alfred Hitchcock
# 10829  John Wayne|Robert Mitchum|James Caan|Charlene ...         Howard Hawks
# 10831  Jack Lemmon|Walter Matthau|Ron Rich|Judi West|...         Billy Wilder
# 10833  Audrey Hepburn|Peter O'Toole|Eli Wallach|Hugh ...        William Wyler
#
#                                                  tagline  \
# 0                                      The park is open.
# 1                                     What a Lovely Day.
# 2                             One Choice Can Destroy You
# 3                          Every generation has a story.
# 4                                    Vengeance Hits Home
# ...                                                  ...
# 10827           He's Here Big As Life In A Real Bat-Epic
# 10828                  It tears you apart with suspense!
# 10829                  It's the Big One with the Big Two
# 10831  Is he a spy? A security risk? Is he unfaithful...
# 10833  A movie about those who appreciate the finest ...
#
#                                                 keywords  runtime  \
# 0      monster|dna|tyrannosaurus rex|velociraptor|island    124.0
# 1       future|chase|post-apocalyptic|dystopia|australia    120.0
# 2      based on novel|revolution|dystopia|sequel|dyst...    119.0
# 3                  android|spaceship|jedi|space opera|3d    136.0
# 4                    car race|speed|revenge|suspense|car    137.0
# ...                                                  ...      ...
# 10827  submarine|dc comics|shark attack|shark|shark r...    105.0
# 10828                              cold war|east germany    128.0
# 10829              sheriff|ranch|liquor|settler|revolver    120.0
# 10831  usa|american football|brother-in-law|wheelchai...    125.0
# 10833  insurance fraud|theft|art thief|swinging 60s|f...    123.0
#
#                                               genres  \
# 0          Action|Adventure|Science Fiction|Thriller
# 1          Action|Adventure|Science Fiction|Thriller
# 2                 Adventure|Science Fiction|Thriller
# 3           Action|Adventure|Science Fiction|Fantasy
# 4                              Action|Crime|Thriller
# ...                                              ...
# 10827  Family|Adventure|Comedy|Science Fiction|Crime
# 10828                               Mystery|Thriller
# 10829                                 Action|Western
# 10831                                 Romance|Comedy
# 10833                           Comedy|Crime|Romance
#
#                                     production_companies release_date  \
# 0      Universal Studios|Amblin Entertainment|Legenda...     6/9/2015
# 1      Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015
# 2      Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015
# 3              Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015
# 4      Universal Pictures|Original Film|Media Rights ...     4/1/2015
# ...                                                  ...          ...
# 10827  Twentieth Century Fox Film Corporation|DC Comi...    7/30/1966
# 10828                                 Universal Pictures    7/13/1966
# 10829              Paramount Pictures|Laurel Productions   12/17/1966
# 10831                                     Phalanx-Jaelem   10/19/1966
# 10833                             World Wide Productions    7/13/1966
#
#        vote_count  vote_average  release_year    budget_adj   revenue_adj  \
# 0            5562           6.5          2015  1.379999e+08  1.392446e+09
# 1            6185           7.1          2015  1.379999e+08  3.481613e+08
# 2            2480           6.3          2015  1.012000e+08  2.716190e+08
# 3            5292           7.5          2015  1.839999e+08  1.902723e+09
# 4            2947           7.3          2015  1.747999e+08  1.385749e+09
# ...           ...           ...           ...           ...           ...
# 10827          99           5.9          1966  9.256081e+06  5.136436e+07
# 10828          46           6.3          1966  2.015404e+07  8.733419e+07
# 10829          36           6.9          1966  3.125892e+07  4.030809e+07
# 10831          17           6.4          1966  1.755104e+07  5.136436e+07
# 10833          67           7.3          1966  1.755104e+07  5.136436e+07
#
#              profit
# 0      1.363529e+09
# 1      2.284364e+08
# 2      1.852382e+08
# 3      1.868178e+09
# 4      1.316249e+09
# ...             ...
# 10827  3.844552e+07
# 10828  1.000000e+07
# 10829  1.347000e+06
# 10831  3.982332e+07
# 10833  3.982332e+07
#
# [5433 rows x 18 columns]

# %%
# average net profit for low_popularity and high_popularity
mean_profit_of_low = lowest_popularity['profit'].mean()
mean_profit_of_high = more_popularity['profit'].mean()
df.head()
# Out:
#    popularity     budget       revenue                original_title  \
# 0   32.985763  150000000  1.513529e+09                Jurassic World
# 1   28.419936  150000000  3.784364e+08            Mad Max: Fury Road
# 2   13.112507  110000000  2.952382e+08                     Insurgent
# 3   11.173104  200000000  2.068178e+09  Star Wars: The Force Awakens
# 4    9.335014  190000000  1.506249e+09                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# 0              The park is open.
# 1             What a Lovely Day.
# 2     One Choice Can Destroy You
# 3  Every generation has a story.
# 4            Vengeance Hits Home
#
#                                             keywords  runtime  \
# 0  monster|dna|tyrannosaurus rex|velociraptor|island    124.0
# 1   future|chase|post-apocalyptic|dystopia|australia    120.0
# 2  based on novel|revolution|dystopia|sequel|dyst...    119.0
# 3              android|spaceship|jedi|space opera|3d    136.0
# 4                car race|speed|revenge|suspense|car    137.0
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...     6/9/2015        5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015        6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015        2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015        5292
# 4  Universal Pictures|Original Film|Media Rights ...     4/1/2015        2947
#
#    vote_average  release_year   budget_adj   revenue_adj        profit
# 0           6.5          2015  137999939.3  1.392446e+09  1.363529e+09
# 1           7.1          2015  137999939.3  3.481613e+08  2.284364e+08
# 2           6.3          2015  101199955.5  2.716190e+08  1.852382e+08
# 3           7.5          2015  183999919.0  1.902723e+09  1.868178e+09
# 4           7.3          2015  174799923.1  1.385749e+09  1.316249e+09

# %%
# create a bar chart with the values we get above 
locations = [1,2]
heights = [mean_profit_of_low, mean_profit_of_high]
labels=['low','high']
plt.bar(locations, heights, tick_label = labels)
plt.title('Average profit by Different Popularity')
plt.xlabel('Popularity')
plt.ylabel('Average Profit')
# Out:
# Text(0, 0.5, 'Average Profit')

# %% [markdown]
# ANSWER FOR QUESTION 3
#
# From the above graph we observe that higher popularity leads to more Average profit.

# %% [markdown]
# EVALUATING QUESTION 4
#
# 4.What are the Features Associate with Top 10 Revenue Movies ?

# %%
top10_revenue = df.nlargest(10,'revenue')
top10_revenue.hist(figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'popularity'}>,
#         <Axes: title={'center': 'budget'}>,
#         <Axes: title={'center': 'revenue'}>],
#        [<Axes: title={'center': 'runtime'}>,
#         <Axes: title={'center': 'vote_count'}>,
#         <Axes: title={'center': 'vote_average'}>],
#        [<Axes: title={'center': 'release_year'}>,
#         <Axes: title={'center': 'budget_adj'}>,
#         <Axes: title={'center': 'revenue_adj'}>],
#        [<Axes: title={'center': 'profit'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ANSWER FOR QUESTION 4
#
# From the above plot we conclude that Runtime ranges from 100 mins to 200 mins.
# The released year are between 1995 to 2015 leads to top 10 revenue movies.

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# 1.Higher budget movie gains higher popularity.
#
# 2.If the movies are within 200 minutes,it will be more popular. Once the movies run over 200 minutes, it's hard for them to gain high popularity.
#
# 3.Higher popularity leads to more Average profit.
#
# 4.Runtime ranges from 100 mins to 200 mins. The released year are between 1995 to 2015 leads to top 10 revenue movies.

# %% [markdown]
# # LIMITATIONS

# %% [markdown]
# 1.There are plenty of missing data and many zeros which effect the data analysis process.
#
# 2.Its very difficult to know how the measurement should be done for coloumn like vote_counts and popularity.
#
# 3.For movies outside the country currency is not indicated. So its also effect the data analysis process.
